# %%
# %run main.py
# Out:
# Using cuDNN version 5110 on context None
# Mapped name None to device cuda: GeForce GTX 950M (0000:01:00.0)
# WARNING (theano.sandbox.cuda): The cuda backend is deprecated and will be removed in the next release (v0.10).  Please switch to the gpuarray backend. You can get more information about how to switch at this URL:
#  https://github.com/Theano/Theano/wiki/Converting-to-the-new-gpu-back-end%28gpuarray%29
# KeyboardInterruptTraceback (most recent call last)
# /home/siam7tong/PycharmProjects/SNN/Spiking-Neural-Network---Theano-Framework-master/Spiking Neural Network/SNN_DEEP_NETWORKS/MNIST/main.py in <module>()
#     387
#     388 if __name__ == '__main__':
# --> 389     train_snn_main()
#     390     # train_count_main()
#
# /home/siam7tong/PycharmProjects/SNN/Spiking-Neural-Network---Theano-Framework-master/Spiking Neural Network/SNN_DEEP_NETWORKS/MNIST/main.py in train_snn_main()
#     372     #     os.makedirs(path)
#     373     print('SNN TRAINING ...')
# ...
